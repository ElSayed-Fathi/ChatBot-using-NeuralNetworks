# %% [markdown]
# ## Import and Load data file

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
# Pickle is used to serialize and deserialize a python object structure.
import pickle
import tensorflow 
import numpy as np
from tensorflow.keras.models import Sequential
# from tf.keras.models import Sequential   The Dropout layer randomly sets input units to 0 with a frequency of rate at each step during training time, which helps prevent overfitting. Inputs not set to 0 are scaled up by 1/(1 - rate) such that the sum over all inputs is unchanged.
#Note that the Dropout layer only applies when training is set to True such that no values are dropped during inference.
from tensorflow.keras.layers import Dense, Activation, Dropout
# gradient descent optimizer Stochastic gradient descent
from tensorflow.keras.optimizers import SGD
import random

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)

# %% [markdown]
# ## Pre-process data

# %% [markdown]
# Here we iterate through the patterns and tokenize the sentence using nltk.word_tokenize() function and append each word in the words list. We also create a list of classes for our tags.

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %% [markdown]
# lemmatize each word and remove duplicate words from the list

# %%
# lemmatize, lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 350 documents
# 99 classes ['Clever', 'CourtesyGoodBye', 'CourtesyGreeting', 'CourtesyGreetingResponse', 'CurrentHumanQuery', 'GoodBye', 'Greeting', 'GreetingResponse', 'Jokes', 'NameQuery', 'NotTalking2U', 'PodBayDoor', 'PodBayDoorResponse', 'RealNameQuery', 'SelfAware', 'Shutup', 'Story', 'Swearing', 'Thanks', 'TimeQuery', 'UnderstandQuery', 'WhoAmI', 'about', 'afternoon', 'anxious', 'ask', 'casual', 'creation', 'death', 'default', 'depressed', 'done', 'evening', 'fact-1', 'fact-10', 'fact-11', 'fact-12', 'fact-13', 'fact-14', 'fact-15', 'fact-16', 'fact-17', 'fact-18', 'fact-19', 'fact-2', 'fact-20', 'fact-21', 'fact-22', 'fact-23', 'fact-24', 'fact-25', 'fact-26', 'fact-27', 'fact-28', 'fact-29', 'fact-3', 'fact-30', 'fact-31', 'fact-32', 'fact-5', 'fact-6', 'fact-7', 'fact-8', 'fact-9', 'friends', 'happy', 'hate-me', 'hate-you', 'help', 'jokes', 'learn-mental-health', 'learn-more', 'location', 'meditation', 'mental-health-fact', 'morning', 'name', 'neutral-response', 'night', 'no-approach', 'no-response', 'not-talking', 'pandora-useful', 'problem', 'repeat', 'sad', 'scared', 'skill', 'sleep', 'something-else', 'stressed', 'stupid', 'suicide', 'understand', 'user-advice', 'user-agree', 'user-meditation', 'worthless', 'wrong']
# 328 unique lemmatized words ["'ll", "'m", "'re", "'s", "'ve", ',', '.', 'a', 'about', 'absolutely', 'adam', 'adios', 'advice', 'affect', 'afternoon', 'again', 'all', 'alot', 'already', 'am', 'and', 'another', 'answer', 'anxiety', 'anxious', 'any', 'anymore', 'anyone', 'anything', 'appears', 'approaching', 'are', 'ask', 'available', 'aware', 'away', 'awful', 'bay', 'be', 'because', 'become', 'before', 'bella', 'better', 'between', 'bored', 'boyfriend', 'break', 'bring', 'brother', 'burned', 'by', 'bye', 'ca', 'call', 'camera', 'can', 'cause', 'cheerful', 'cheering', 'child', 'clever', 'commit', 'communicating', 'comprendo', 'connection', 'conscious', 'continue', 'control', 'could', 'crazy', 'created', 'cure', 'dad', 'day', 'define', 'depressed', 'depression', 'deserve', 'did', 'die', 'died', 'difference', 'different', 'disorder', 'do', 'doe', 'doing', 'door', 'down', 'dumb', 'else', 'empty', 'enough', 'evening', 'exam', 'fact', 'family', 'feel', 'feeling', 'few', 'financial', 'find', 'fine', 'focus', 'for', 'friend', 'from', 'fuck', 'genious', 'get', 'girl', 'girlfriend', 'give', 'go', 'going', 'good', 'goodbye', 'got', 'great', 'group', 'guess', 'had', 'hand', 'happy', 'hate', 'have', 'health', 'hear', 'hello', 'help', 'helpful', 'hi', 'hmmm', 'hola', 'hope', 'how', 'hya', 'i', 'identify', 'if', 'ill', 'illness', 'importance', 'important', 'in', 'insominia', 'insomnia', 'intelligent', 'interested', 'involved', 'is', 'it', 'joke', 'just', 'k', 'kill', 'killing', 'know', 'last', 'later', 'laugh', 'learn', 'learning', 'let', 'like', 'live', 'location', 'lonely', 'made', 'maintain', 'make', 'me', 'mean', 'meant', 'medication', 'meditation', 'mental', 'mentally', 'mentioned', 'mom', 'money', 'more', 'morning', 'much', 'my', 'myself', "n't", 'name', 'need', 'new', 'nice', 'night', 'no', 'nobody', 'not', 'nothing', 'now', 'of', 'off', 'oh', 'ok', 'okay', 'on', 'one', 'open', 'option', 'or', 'out', 'passed', 'past', 'people', 'please', 'pod', 'possibly', 'practicing', 'prepared', 'prevent', 'probably', 'problem', 'professional', 'proper', 'prove', 'quiet', 'real', 'really', 'recover', 'relationship', 'repeating', 'response', 'right', 'robot', 'sad', 'sadness', 'said', 'say', 'saying', 'scared', 'see', 'seem', 'self', 'self-aware', 'sense', 'shhh', 'shit', 'should', 'shut', 'sign', 'sister', 'sleep', 'slept', 'so', 'social', 'some', 'someone', 'something', 'sound', 'speaking', 'starting', 'stay', 'still', 'stop', 'story', 'stoties', 'stress', 'stressed', 'stuck', 'stupid', 'suffering', 'suicide', 'support', 'sure', 'surely', 'symptom', 'take', 'talk', 'talking', 'tell', 'thank', 'thanks', 'that', 'the', 'therapist', 'therapy', 'there', 'think', 'this', 'thought', 'through', 'time', 'to', 'today', 'told', 'treatment', 'trust', 'twat', 'type', 'understand', 'understands', 'unwell', 'up', 'useful', 'useless', 'user', 'very', 'wa', 'want', 'warning', 'way', 'we', 'well', 'were', 'what', 'whatever', 'where', 'who', 'why', 'will', 'with', 'worried', 'worthless', 'would', 'wrong', 'yeah', 'yes', 'you', 'your', 'yourself']

# %% [markdown]
# ## Create training and testing data

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# C:\Users\METRA\AppData\Local\Temp\ipykernel_3052\2451131480.py:24: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)

# %% [markdown]
# ## Create Model

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
#Batch size is a term used in machine learning and refers to the number of training examples utilized in one iteration.
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# E:\anacondaaa\envs\tf-gpu\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Epoch 1/200
# 70/70 [==============================] - 3s 9ms/step - loss: 4.6088 - accuracy: 0.0200
# Epoch 2/200
# 70/70 [==============================] - 1s 9ms/step - loss: 4.5149 - accuracy: 0.0371
# Epoch 3/200
# 70/70 [==============================] - 1s 9ms/step - loss: 4.4153 - accuracy: 0.0486
# Epoch 4/200
# 70/70 [==============================] - 1s 9ms/step - loss: 4.3052 - accuracy: 0.0629
# Epoch 5/200
# 70/70 [==============================] - 1s 8ms/step - loss: 4.1080 - accuracy: 0.0914
# Epoch 6/200
# 70/70 [==============================] - 1s 8ms/step - loss: 3.9565 - accuracy: 0.0800
# Epoch 7/200
# 70/70 [==============================] - 1s 9ms/step - loss: 3.7774 - accuracy: 0.1429
# Epoch 8/200
# 70/70 [==============================] - 1s 9ms/step - loss: 3.5414 - accuracy: 0.1771
# Epoch 9/200
# 70/70 [==============================] - 1s 9ms/step - loss: 3.4849 - accuracy: 0.1629
# Epoch 10/200
# 70/70 [==============================] - 1s 11ms/step - loss: 3.1990 - accuracy: 0.1971
# Epoch 11/200
# 70/70 [==============================] - 1s 11ms/step - loss: 3.1369 - accuracy: 0.2286
# Epoch 12/200
# 70/70 [==============================] - 1s 10ms/step - loss: 2.8692 - accuracy: 0.3000
# Epoch 13/200
# 70/70 [==============================] - 1s 9ms/step - loss: 2.7821 - accuracy: 0.3029
# Epoch 14/200
# 70/70 [==============================] - 1s 9ms/step - loss: 2.5237 - accuracy: 0.3514
# Epoch 15/200
# 70/70 [==============================] - 1s 8ms/step - loss: 2.4800 - accuracy: 0.3743
# Epoch 16/200
# 70/70 [==============================] - 1s 8ms/step - loss: 2.4061 - accuracy: 0.3714
# Epoch 17/200
# 70/70 [==============================] - 1s 8ms/step - loss: 2.2534 - accuracy: 0.4314
# Epoch 18/200
# 70/70 [==============================] - 1s 9ms/step - loss: 2.1503 - accuracy: 0.4086
# Epoch 19/200
# 70/70 [==============================] - 1s 9ms/step - loss: 2.1579 - accuracy: 0.4200
# Epoch 20/200
# 70/70 [==============================] - 1s 9ms/step - loss: 2.0528 - accuracy: 0.4743
# Epoch 21/200
# 70/70 [==============================] - 1s 10ms/step - loss: 1.9775 - accuracy: 0.4457
# Epoch 22/200
# 70/70 [==============================] - 1s 9ms/step - loss: 1.8306 - accuracy: 0.5029
# Epoch 23/200
# 70/70 [==============================] - 1s 9ms/step - loss: 1.8221 - accuracy: 0.5200
# Epoch 24/200
# 70/70 [==============================] - 1s 8ms/step - loss: 1.7718 - accuracy: 0.4829
# Epoch 25/200
# 70/70 [==============================] - 1s 8ms/step - loss: 1.6684 - accuracy: 0.5114
# Epoch 26/200
# 70/70 [==============================] - 1s 8ms/step - loss: 1.5763 - accuracy: 0.5600
# Epoch 27/200
# 70/70 [==============================] - 1s 9ms/step - loss: 1.6156 - accuracy: 0.5429
# Epoch 28/200
# 70/70 [==============================] - 1s 9ms/step - loss: 1.4438 - accuracy: 0.5886
# Epoch 29/200
# 70/70 [==============================] - 1s 9ms/step - loss: 1.5259 - accuracy: 0.5657
# Epoch 30/200
# 70/70 [==============================] - 1s 8ms/step - loss: 1.3243 - accuracy: 0.6343
# Epoch 31/200
# 70/70 [==============================] - 1s 9ms/step - loss: 1.3973 - accuracy: 0.6029
# Epoch 32/200
# 70/70 [==============================] - 1s 9ms/step - loss: 1.2753 - accuracy: 0.6229
# Epoch 33/200
# 70/70 [==============================] - 1s 9ms/step - loss: 1.2685 - accuracy: 0.6371
# Epoch 34/200
# 70/70 [==============================] - 1s 9ms/step - loss: 1.1719 - accuracy: 0.6629
# Epoch 35/200
# 70/70 [==============================] - 1s 10ms/step - loss: 1.2638 - accuracy: 0.6257
# Epoch 36/200
# 70/70 [==============================] - 1s 9ms/step - loss: 1.2687 - accuracy: 0.5971
# Epoch 37/200
# 70/70 [==============================] - 1s 8ms/step - loss: 1.2401 - accuracy: 0.6371
# Epoch 38/200
# 70/70 [==============================] - 1s 9ms/step - loss: 1.0674 - accuracy: 0.6943
# Epoch 39/200
# 70/70 [==============================] - 1s 9ms/step - loss: 1.1228 - accuracy: 0.6857
# Epoch 40/200
# 70/70 [==============================] - 1s 9ms/step - loss: 1.1795 - accuracy: 0.6400
# Epoch 41/200
# 70/70 [==============================] - 1s 9ms/step - loss: 1.1072 - accuracy: 0.6571
# Epoch 42/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.9801 - accuracy: 0.7257
# Epoch 43/200
# 70/70 [==============================] - 1s 9ms/step - loss: 1.0260 - accuracy: 0.6914
# Epoch 44/200
# 70/70 [==============================] - 1s 9ms/step - loss: 1.0288 - accuracy: 0.6771
# Epoch 45/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.9354 - accuracy: 0.7143
# Epoch 46/200
# 70/70 [==============================] - 1s 9ms/step - loss: 1.0559 - accuracy: 0.7114
# Epoch 47/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.9743 - accuracy: 0.7000
# Epoch 48/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.9746 - accuracy: 0.7086
# Epoch 49/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8865 - accuracy: 0.7429
# Epoch 50/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8822 - accuracy: 0.7200
# Epoch 51/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.9394 - accuracy: 0.7171
# Epoch 52/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.9982 - accuracy: 0.7114
# Epoch 53/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8973 - accuracy: 0.7257
# Epoch 54/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.9505 - accuracy: 0.7371
# Epoch 55/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.9859 - accuracy: 0.6829
# Epoch 56/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8327 - accuracy: 0.7429
# Epoch 57/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8825 - accuracy: 0.7286
# Epoch 58/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7852 - accuracy: 0.7857
# Epoch 59/200
# 70/70 [==============================] - 1s 10ms/step - loss: 0.7954 - accuracy: 0.7629
# Epoch 60/200
# 70/70 [==============================] - 1s 10ms/step - loss: 0.8296 - accuracy: 0.7600
# Epoch 61/200
# 70/70 [==============================] - 1s 10ms/step - loss: 0.9161 - accuracy: 0.7143
# Epoch 62/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7640 - accuracy: 0.7829
# Epoch 63/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7389 - accuracy: 0.7743
# Epoch 64/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7303 - accuracy: 0.7886
# Epoch 65/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7666 - accuracy: 0.7714
# Epoch 66/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7769 - accuracy: 0.7457
# Epoch 67/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8117 - accuracy: 0.7486
# Epoch 68/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7436 - accuracy: 0.7714
# Epoch 69/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.7114 - accuracy: 0.7914
# Epoch 70/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7654 - accuracy: 0.7629
# Epoch 71/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7514 - accuracy: 0.7857
# Epoch 72/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7823 - accuracy: 0.7600
# Epoch 73/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6938 - accuracy: 0.7714
# Epoch 74/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8223 - accuracy: 0.7514
# Epoch 75/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5519 - accuracy: 0.8314
# Epoch 76/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6994 - accuracy: 0.7771
# Epoch 77/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6648 - accuracy: 0.8000
# Epoch 78/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8187 - accuracy: 0.7229
# Epoch 79/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5888 - accuracy: 0.7943
# Epoch 80/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.7206 - accuracy: 0.7943
# Epoch 81/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6980 - accuracy: 0.7771
# Epoch 82/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6710 - accuracy: 0.8029
# Epoch 83/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6633 - accuracy: 0.7800
# Epoch 84/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8061 - accuracy: 0.7714
# Epoch 85/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7047 - accuracy: 0.7800
# Epoch 86/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7588 - accuracy: 0.7457
# Epoch 87/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7438 - accuracy: 0.7943
# Epoch 88/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5634 - accuracy: 0.8343
# Epoch 89/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6752 - accuracy: 0.8057
# Epoch 90/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.7408 - accuracy: 0.7771
# Epoch 91/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6421 - accuracy: 0.7943
# Epoch 92/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.7229 - accuracy: 0.7886
# Epoch 93/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.7639 - accuracy: 0.7714
# Epoch 94/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6824 - accuracy: 0.8000
# Epoch 95/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6531 - accuracy: 0.7829
# Epoch 96/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6280 - accuracy: 0.8000
# Epoch 97/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.7095 - accuracy: 0.7686
# Epoch 98/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.8417 - accuracy: 0.7514
# Epoch 99/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6324 - accuracy: 0.7971
# Epoch 100/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6310 - accuracy: 0.8057
# Epoch 101/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6644 - accuracy: 0.8057
# Epoch 102/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5854 - accuracy: 0.8200
# Epoch 103/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6523 - accuracy: 0.8057
# Epoch 104/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6782 - accuracy: 0.7857
# Epoch 105/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.7409 - accuracy: 0.7743
# Epoch 106/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6517 - accuracy: 0.7943
# Epoch 107/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6686 - accuracy: 0.7914
# Epoch 108/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6047 - accuracy: 0.8143
# Epoch 109/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6557 - accuracy: 0.7857
# Epoch 110/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6985 - accuracy: 0.7971
# Epoch 111/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6200 - accuracy: 0.8000
# Epoch 112/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5893 - accuracy: 0.8200
# Epoch 113/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5662 - accuracy: 0.8171
# Epoch 114/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5825 - accuracy: 0.8429
# Epoch 115/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5524 - accuracy: 0.8400
# Epoch 116/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6192 - accuracy: 0.8143
# Epoch 117/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5465 - accuracy: 0.8286
# Epoch 118/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6657 - accuracy: 0.7886
# Epoch 119/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5157 - accuracy: 0.8400
# Epoch 120/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5904 - accuracy: 0.8229
# Epoch 121/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6078 - accuracy: 0.8000
# Epoch 122/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5832 - accuracy: 0.8171
# Epoch 123/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5588 - accuracy: 0.8143
# Epoch 124/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.7158 - accuracy: 0.7800
# Epoch 125/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5966 - accuracy: 0.8086
# Epoch 126/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5984 - accuracy: 0.8086
# Epoch 127/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5179 - accuracy: 0.8286
# Epoch 128/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6053 - accuracy: 0.8200
# Epoch 129/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6716 - accuracy: 0.8257
# Epoch 130/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6263 - accuracy: 0.8086
# Epoch 131/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6061 - accuracy: 0.8314
# Epoch 132/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.4997 - accuracy: 0.8314
# Epoch 133/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6304 - accuracy: 0.8257
# Epoch 134/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5287 - accuracy: 0.8486
# Epoch 135/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5530 - accuracy: 0.8200
# Epoch 136/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5697 - accuracy: 0.8229
# Epoch 137/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.7430 - accuracy: 0.7943
# Epoch 138/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5488 - accuracy: 0.8257
# Epoch 139/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5002 - accuracy: 0.8143
# Epoch 140/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5692 - accuracy: 0.8286
# Epoch 141/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5337 - accuracy: 0.8229
# Epoch 142/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5612 - accuracy: 0.8343
# Epoch 143/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5464 - accuracy: 0.8257
# Epoch 144/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6219 - accuracy: 0.8057
# Epoch 145/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5048 - accuracy: 0.8400
# Epoch 146/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6424 - accuracy: 0.8114
# Epoch 147/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5285 - accuracy: 0.8314
# Epoch 148/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5973 - accuracy: 0.8143
# Epoch 149/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6402 - accuracy: 0.7743
# Epoch 150/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6070 - accuracy: 0.8314
# Epoch 151/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6377 - accuracy: 0.7857
# Epoch 152/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.4917 - accuracy: 0.8514
# Epoch 153/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5733 - accuracy: 0.8257
# Epoch 154/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6358 - accuracy: 0.8171
# Epoch 155/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6834 - accuracy: 0.8029
# Epoch 156/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5469 - accuracy: 0.8200
# Epoch 157/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6549 - accuracy: 0.8029
# Epoch 158/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6115 - accuracy: 0.8400
# Epoch 159/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5360 - accuracy: 0.8314
# Epoch 160/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5391 - accuracy: 0.8257
# Epoch 161/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5079 - accuracy: 0.8286
# Epoch 162/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6291 - accuracy: 0.8057
# Epoch 163/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6553 - accuracy: 0.8114
# Epoch 164/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6267 - accuracy: 0.8257
# Epoch 165/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5656 - accuracy: 0.8314
# Epoch 166/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.4269 - accuracy: 0.8686
# Epoch 167/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5576 - accuracy: 0.8400
# Epoch 168/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6116 - accuracy: 0.8057
# Epoch 169/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6154 - accuracy: 0.8257
# Epoch 170/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5991 - accuracy: 0.8114
# Epoch 171/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5712 - accuracy: 0.8429
# Epoch 172/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6586 - accuracy: 0.8086
# Epoch 173/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.4611 - accuracy: 0.8543
# Epoch 174/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6445 - accuracy: 0.8286
# Epoch 175/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6300 - accuracy: 0.8029
# Epoch 176/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5673 - accuracy: 0.8343
# Epoch 177/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5895 - accuracy: 0.8086
# Epoch 178/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5169 - accuracy: 0.8400
# Epoch 179/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5102 - accuracy: 0.8457
# Epoch 180/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6184 - accuracy: 0.8257
# Epoch 181/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6769 - accuracy: 0.8029
# Epoch 182/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6289 - accuracy: 0.8143
# Epoch 183/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5860 - accuracy: 0.8371
# Epoch 184/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5044 - accuracy: 0.8371
# Epoch 185/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5506 - accuracy: 0.8343
# Epoch 186/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6132 - accuracy: 0.8229
# Epoch 187/200
# 70/70 [==============================] - 1s 10ms/step - loss: 0.5448 - accuracy: 0.8457
# Epoch 188/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5239 - accuracy: 0.8257
# Epoch 189/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6591 - accuracy: 0.7971
# Epoch 190/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5617 - accuracy: 0.8229
# Epoch 191/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5879 - accuracy: 0.8429
# Epoch 192/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5199 - accuracy: 0.8543
# Epoch 193/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5958 - accuracy: 0.8400
# Epoch 194/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6556 - accuracy: 0.7971
# Epoch 195/200
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6162 - accuracy: 0.8457
# Epoch 196/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5422 - accuracy: 0.8371
# Epoch 197/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6616 - accuracy: 0.8086
# Epoch 198/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5520 - accuracy: 0.8229
# Epoch 199/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.4221 - accuracy: 0.8629
# Epoch 200/200
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6774 - accuracy: 0.8229
# model created

# %%
from tensorflow.keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

# %%
def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words) 
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

# %%
def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %%
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

# %%
def chatbot_response(text):
    ints = predict_class(text, model)
    res = getResponse(ints, intents)
    return res

# %% [markdown]
# ## GUI Interface

# %%
import tkinter
from tkinter import *


def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)
    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))

        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')

        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)
        
        
base = Tk()
base.title("Hello")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)


#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)

ChatLog.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )

#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="40", height="5", font="Arial", background="#dddddd")
#EntryBox.bind("<Return>", send)


#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=130, y=401, height=40, width=265)
SendButton.place(x=6, y=401, height=40)

# %%
base.mainloop()
